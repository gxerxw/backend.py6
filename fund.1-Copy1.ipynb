# %% [markdown]
# #· COMM primer ejemplo

# %%
A = "Backend.py6"
print("El ejemplo es: ",A)
# Out:
# El ejemplo es:  Backend.py6

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# ## Caract. escape

# %%
"\ ´" #single quote
# Out:
# '\\ ´'

# %%
"\n" # New line / salto de linea
# Out:
# '\n'

# %%
my_example = "backendpy.6 de geram"
print(my_example)
# Out:
# backendpy.6 de geram

# %%
my_example = "backendpy.6\n de geram"
print(my_example)
# Out:
# backendpy.6
#  de geram

# %%
"\t" # tab
# Out:
# '\t'

# %%
my_example = "backendpy.6 de geram"
print(my_example)
# Out:
# backendpy.6 de geram

# %%
my_example = "backendpy.6\tde geram"
print(my_example)
# Out:
# backendpy.6	de geram

# %%
"\r" # carriage return/ retorno de carro
# Out:
# '\r'

# %%
my_example = "backendpy.6 de\r geram"
print(my_example)
# Out:
#  geram

# %%
my_example = "backendpy.6 de \rgeram"
print(my_example)
# Out:
# geram

# %%
"\b" #backspace/ retorno
# Out:
# '\x08'

# %%
my_example = "backendpy.6 de\r geram"
print(my_example)
# Out:
#  geram

# %%
my_example = "backendpy.6 de geram"
print(my_example)
# Out:
# backendpy.6 de geram

# %%
my_example = "backendpy.6\b de geram"
print(my_example)
# Out:
#  de geram

# %%
"\ooo" #octal
# Out:
# '\\ooo'

# %%
here_english_octal = "117\223\147\333"
print(here_english_octal)
# Out:
# 117gÛ

# %%
here_english_octal = "\117\223\147\333"
print(here_english_octal)
# Out:
# OgÛ

# %%
hello_english_octal = "\117\223\147\333"

# %%
hello_english_octal = "\117\223\147\333"
print(hello_english_octal)
# Out:
# OgÛ

# %%
"\xhh" ·exadesimal
# Out:
#   Cell In[23], line 1
#     "\xhh" ·exadesimal
#            ^
# SyntaxError: invalid character '·' (U+00B7)

# %%
"\xhh" #exadesimal
# Out:
#   Cell In[24], line 1
#     "\xhh" #exadesimal
#            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \xXX escape

# %%
"\xhh" #Hexadecimal
# Out:
#   Cell In[25], line 1
#     "\xhh" #Hexadecimal
#            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \xXX escape

# %%
#"xhh" #Hexadecimal

# %%
here_english_hex = "\x48\x6f\x6c\x61"
print(here_english_hex)
# Out:
# Hola

# %% [markdown]
# ## Función print()

# %%
a=100
b=200
c=300
d=a+b+c
print("el valor de d es: ",d)
# Out:
# el valor de d es:  600

# %%
help(ptint)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 help(ptint)
#
# NameError: name 'ptint' is not defined

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
dir(builtins)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dir(builtins)
#
# NameError: name 'builtins' is not defined

# %%
dir(builtins)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dir(builtins)
#
# NameError: name 'builtins' is not defined

# %%
my boolean = True
print:(my_boolean)
print(type(my_boolean))
# Out:
#   Cell In[6], line 1
#     my boolean = True
#        ^
# SyntaxError: invalid syntax

# %%
my boolean = True
print(my_boolean)
print(type(my_boolean))
# Out:
#   Cell In[7], line 1
#     my boolean = True
#        ^
# SyntaxError: invalid syntax

# %%
my boolean = True
print:(my_boolean)
print(type(my_boolean))
# Out:
#   Cell In[8], line 1
#     my boolean = True
#        ^
# SyntaxError: invalid syntax

# %%
my_boolean = True
print:(my_boolean)
print(type(my_boolean))
# Out:
# <class 'bool'>

# %%
my boolean = False
print:(my_boolean)
print(type(my_boolean))
# Out:
#   Cell In[10], line 1
#     my boolean = False
#        ^
# SyntaxError: invalid syntax

# %%
my_boolean = False
print:(my_boolean)
print(type(my_boolean))
# Out:
# <class 'bool'>

# %%
my_list=[1, 7, 4, 2]
print(my_list)
print(type(my_list))
# Out:
# [1, 7, 4, 2]
# <class 'list'>

# %%
my_boolean=False
print(my_boolean)
print(type(my_boolean))
# Out:
# False
# <class 'bool'>

# %%
my_tuple=(3,6,9,12)
print(my_tuple)
print(type(my_tuple))
# Out:
# (3, 6, 9, 12)
# <class 'tuple'>

# %%
my_set{2,7 backend.py6 4,8}
# Out:
#   Cell In[15], line 1
#     my_set{2,7 backend.py6 4,8}
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
my_set{2,7 backend.py6 4,8}
print(my_set)
print(type(my_set))
# Out:
#   Cell In[16], line 1
#     my_set{2,7 backend.py6 4,8}
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
my_set{2,7 "backend.py6", 4,8}
print(my_set)
print(type(my_set))
# Out:
#   Cell In[17], line 1
#     my_set{2,7 "backend.py6", 4,8}
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
my_set{2,7, "backend.py6", 4,8}
print(my_set)
print(type(my_set))
# Out:
#   Cell In[18], line 1
#     my_set{2,7, "backend.py6", 4,8}
#           ^
# SyntaxError: invalid syntax

# %%
my_float=3.92
print(my_float)
printe(type(my_float))
# Out:
# 3.92
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 my_float=3.92
#       2 print(my_float)
# ----> 3 printe(type(my_float))
#
# NameError: name 'printe' is not defined

# %%
my_float=3.92
print(my_float)
print(type(my_float))
# Out:
# 3.92
# <class 'float'>

# %%
my_set{2,7, "backend.py6", 4.8}
print(my_set)
print(type(my_set))
# Out:
#   Cell In[21], line 1
#     my_set{2,7, "backend.py6", 4.8}
#           ^
# SyntaxError: invalid syntax

# %%
my_set{2,7, "backendpy6", 48}
print(my_set)
print(type(my_set))
# Out:
#   Cell In[22], line 1
#     my_set{2,7, "backendpy6", 48}
#           ^
# SyntaxError: invalid syntax

# %%
my_set={2,7, "backend.py6", 4.8}
print(my_set)
print(type(my_set))
# Out:
# {2, 'backend.py6', 4.8, 7}
# <class 'set'>

# %%
my_set={2,7, "backendpy6", 4.8}
print(my_set)
print(type(my_set))
# Out:
# {'backendpy6', 2, 4.8, 7}
# <class 'set'>

# %%
my_directory={"a":20, "b":35, "c":50}
print(my_directory)
print(type(my_directory))
# Out:
# {'a': 20, 'b': 35, 'c': 50}
# <class 'dict'>

# %% [markdown]
# #Función Id()

# %% [markdown]
# ## Función para obtener dirección de memoria

# %%
my_directory={"a":20, "b":35, "c":50}
print(my_directory)
print(type(my_directory))
print(id(,y_directory))
# Out:
#   Cell In[26], line 4
#     print(id(,y_directory))
#              ^
# SyntaxError: invalid syntax

# %%
my_directory={"a":20, "b":35, "c":50}
print(my_directory)
print(type(my_directory))
print(id(my_directory))
# Out:
# {'a': 20, 'b': 35, 'c': 50}
# <class 'dict'>
# 2205548352640

# %%
my_directory={"a":20, "b":35, "c":50}
my_directory2={"a":20, "b":35, "c":50}
print(my_directory)
print(my_directory2)
print(type(my_directory))
print(type(my_directory2))
print(id(my_directory))
print(id(my_directory2))
# Out:
# {'a': 20, 'b': 35, 'c': 50}
# {'a': 20, 'b': 35, 'c': 50}
# <class 'dict'>
# <class 'dict'>
# 2205548880640
# 2205548812864

# %%
my_boolean=False
my_boolean2=False
print(my_boolean)
print(my_boolean2)
print(type(my_boolean))
print(type(my_boolean2))
print(id(my_boolean))
print(id(my_boolean))
# Out:
# False
# False
# <class 'bool'>
# <class 'bool'>
# 140722982758976
# 140722982758976

# %% [markdown]
# ## Valores de entrada

# %%
my_number = input ("ingresa el valor de my_number: ")
print("el valor de my_number es: ", my_number)
# Out:
# ingresa el valor de my_number: 37
# el valor de my_number es:  37

# %%
z,x = input ("ingresa los 2 valores: ").split()
print("el valor de z es: ",z)
print("el valor de x es: ",x)
# Out:
# ingresa los 2 valores: 51 47
# el valor de z es:  51
# el valor de x es:  47

# %%
mi_dicc = {
    "a":1,
    "b":2,
    "c":3
for clave, valor in mi_dicc.items():
    print:(clave, valor)
# Out:
#   Cell In[32], line 1
#     mi_dicc = {
#               ^
# SyntaxError: '{' was never closed

# %%
mi_dicc = {}
    "a":1,
    "b":2,
    "c":3
for clave, valor in mi_dicc.items():
    print:(clave, valor)
# Out:
#   Cell In[33], line 2
#     "a":1,
#     ^
# IndentationError: unexpected indent

# %%
mi_dicc = {
}
    "a":1,
    "b":2,
    "c":3
for clave, valor in mi_dicc.items():
    print:(clave, valor)
# Out:
#   Cell In[34], line 3
#     "a":1,
#     ^
# IndentationError: unexpected indent

# %%
mi_dicc = {
}
    "a": 1,
    "b": 2,
    "c": 3
for clave, valor in mi_dicc.items():
    print:(clave, valor)
# Out:
#   Cell In[35], line 3
#     "a": 1,
#     ^
# IndentationError: unexpected indent

# %%
mi_dicc = {
    "a":1,
    "b":2,
    "c":3
}
for clave, valor in mi_dicc.items():
    print:(clave, valor)

# %%
mi_dicc = {
    "a":1,
    "b":2,
    "c":3
}
for clave, valor in mi_dicc.items():
    print:(clave, valor)

# %%
mi_dicc = {
    "a":1,
    "b":2,
    "c":3
}
for valor in mi_dicc.values():
    print:(valor)

# %%
color = "verde"

print(f"Hey, mi color favorito es: {color}")
# Out:
# Hey, mi color favorito es: verde

# %%
color = "verde"

print(f"Hey, mi color favorito es {color}")
# Out:
# Hey, mi color favorito es verde

# %%
color = "verde"

print(f"Hey, mi color favorito es el {color}")
# Out:
# Hey, mi color favorito es el verde

# %%
color = "verde"

print(f"Hey,¿cuál es tu color favorito?").split()
print(f"Mi color favorito es el [color]")
# Out:
# Hey,¿cuál es tu color favorito?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 3
#       1 color = "verde"
# ----> 3 print(f"Hey,¿cuál es tu color favorito?").split()
#       4 print(f"Mi color favorito es el [color]")
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
color = "verde"

print(f"Hey,¿cuál es tu color favorito?")
print(f"Mi color favorito es el [color]")
# Out:
# Hey,¿cuál es tu color favorito?
# Mi color favorito es el [color]

# %%
color = "verde"

print(f"Hey,¿cuál es tu color favorito?").split()
print(f"Mi color favorito es el ´{color}")
# Out:
# Hey,¿cuál es tu color favorito?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 3
#       1 color = "verde"
# ----> 3 print(f"Hey,¿cuál es tu color favorito?").split()
#       4 print(f"Mi color favorito es el ´{color}")
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
color = "verde"

print(f"Hey,¿cuál es tu color favorito?")
print(f"Mi color favorito es el {color}")
# Out:
# Hey,¿cuál es tu color favorito?
# Mi color favorito es el verde

# %%
color = "verde"

print(f"Hey, ¿cuál es tu color favorito?")
print(f"Mi color favorito es el {color}")
print(f"Genial, el mío es el púrpura")
# Out:
# Hey, ¿cuál es tu color favorito?
# Mi color favorito es el verde
# Genial, el mío es el púrpura

# %%
z,x = input ("ingresa los 2 valores: ").split()
print("el valor de z es: ",z)
print("el valor de x es: ",x)

 valor = "98"
    print(f" ¿Cuál es el valor de z + x?")
    print(f"R: 98")
# Out:
#   Cell In[47], line 5
#     valor = "98"
#     ^
# IndentationError: unexpected indent

# %%
z,x = input ("ingresa los 2 valores: ").split()
print("el valor de z es: ",z)
print("el valor de x es: ",x)
 valor = "98"
    print(f" ¿Cuál es el valor de z + x?")
    print(f"R: 98")
# Out:
#   Cell In[48], line 4
#     valor = "98"
#     ^
# IndentationError: unexpected indent

# %%
z,x = input ("ingresa los 2 valores: ").split()
print("el valor de z es: ",z)
print("el valor de x es: ",x)

 valor = input ("98")
    print(f" ¿Cuál es el valor de z + x?")
    print(f"R: 98")
# Out:
#   Cell In[49], line 5
#     valor = input ("98")
#     ^
# IndentationError: unexpected indent

# %%
z,x = input ("ingresa los 2 valores: ").split()
print("el valor de z es: ",z)
print("el valor de x es: ",x)

 valor = "98"
    print(f" ¿Cuál es el valor de z + x?")
    print(f"R: {valor}")
# Out:
#   Cell In[50], line 5
#     valor = "98"
#     ^
# IndentationError: unexpected indent

# %%
z,x = input ("ingresa los 2 valores: ").split()
print("el valor de z es: ",z)
print("el valor de x es: ",x)
\n
 valor = "98"
    print(f" ¿Cuál es el valor de z + x?")
    print(f"Equivale a: " {valor})
# Out:
#   Cell In[51], line 4
#     \n
#      ^
# SyntaxError: unexpected character after line continuation character

# %%
z,x = input ("ingresa los 2 valores: ").split()
print("el valor de z es: ",z)
print("el valor de x es: ",x)
print(" ¿Cuál es el valor de la suma entre z y x? ")
print("Resultado: ")
# Out:
# ingresa los 2 valores: 51 47
# el valor de z es:  51
# el valor de x es:  47
#  ¿Cuál es el valor de la suma entre z y x?
# Resultado:

# %%
z,x = input ("ingresa los 2 valores: ").split()
print("el valor de z es: ",z)
print("el valor de x es: ",x)
print(" ¿Cuál es el valor de la suma entre z y x? ")
print("Resultado: ")
# Out:
# ingresa los 2 valores: z 47
# el valor de z es:  z
# el valor de x es:  47
#  ¿Cuál es el valor de la suma entre z y x?
# Resultado:

# %%
z,x = input ("ingresa los 2 valores: ").split()
print("el valor de z es: ",?)
print("el valor de x es: ",x)
print(" ¿Cuál es el valor de la suma entre z y x? ")
print("Resultado: ")
# Out:
#   Cell In[54], line 2
#     print("el valor de z es: ",?)
#                                ^
# SyntaxError: invalid syntax

# %%
z,x = input ("ingresa los 2 valores: ").split()
print("el valor de z es: ",z)
print("el valor de x es: ",x)
print(" ¿Cuál es el valor de la suma entre z y x? ")
print("Resultado: ")
# Out:
# ingresa los 2 valores: ? 47
# el valor de z es:  ?
# el valor de x es:  47
#  ¿Cuál es el valor de la suma entre z y x?
# Resultado:

# %%
z,x = input ("ingresa los 2 valores separados por coma: ").split(",")
print("el valor de z es: ",z)
print("el valor de x es: ",x)
print(" ¿Cuál es el valor de la suma entre z y x? ")
print("Resultado: ")
# Out:
# ingresa los 2 valores separados por coma: ?, 47
# el valor de z es:  ?
# el valor de x es:   47
#  ¿Cuál es el valor de la suma entre z y x?
# Resultado:

# %%
z,x = input ("ingresa los 2 valores separados por coma: ").split(",")
print("el valor de z es: ",z)
print("el valor de x es: ",x)
print(" ¿Cuál es el valor de la suma entre z y x? ")
print("Resultado: ")
# Out:
# ingresa los 2 valores separados por coma: 51, 47
# el valor de z es:  51
# el valor de x es:   47
#  ¿Cuál es el valor de la suma entre z y x?
# Resultado:
